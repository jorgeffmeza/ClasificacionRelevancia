# %%
import pandas as pd
import numpy as np
import string
import os
import re, string
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout, Input, Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D, MaxPooling1D, BatchNormalization, SpatialDropout1D, GlobalAveragePooling1D, concatenate, Activation, LSTM, Bidirectional
from keras import initializers, regularizers, constraints, optimizers, layers, callbacks
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import StratifiedKFold, cross_val_score, KFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#/content/drive/MyDrive/Ordenar/DSRP/df.xlsx
mainpath = '/content/drive/MyDrive/Ordenar/DSRP/'
filename = 'train.xlsx'
fullpath = os.path.join(mainpath, 'train.xlsx')
train=pd.read_excel(fullpath, usecols=['Comentario','Clasificación'])

fullpath = os.path.join(mainpath, 'test.xlsx')
test=pd.read_excel(fullpath, usecols=['Comentario','Clasificación'])

# %%
import re                                  # library for regular expression operations
import string                              # for string operations

from nltk.corpus import stopwords          # module for stop words that come with NLTK
from nltk.stem import PorterStemmer        # module for stemming
from nltk.tokenize import regexp_tokenize   # module for tokenizing strings
from nltk.tokenize import TreebankWordTokenizer

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*¿!¡?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
train['Comentario'] = train['Comentario'].apply(lambda x: clean_text(x))
test['Comentario']= test['Comentario'].apply(lambda x: clean_text(x))

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
train.shape, test.shape
# Out:
# ((15728, 2), (3932, 2))

# %%
#print('Loading data...')
#train = pd.read_csv(r"train.csv")
#test = pd.read_csv(r"test.csv")
#test_labels = pd.read_csv(r"test_labels.csv")

#test = pd.concat([test, test_labels], axis=1)
#test = test[test['toxic']!=-1]

classes = ["Clasificación"]
y_train = train[classes].values
y_test = test[classes].values

train_sentences = train["Comentario"].fillna("fillna")
test_sentences = test["Comentario"].fillna("fillna")

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/00/92/6153f4912b84ee1ab53ab45663d23e7cf3704161cb5ef18b0c07e207cef2/transformers-4.7.0-py3-none-any.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 14.4MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from transformers) (3.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.5.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/d4/e2/df3543e8ffdab68f5acc73f613de9c2b155ac47f162e725dcac87c521c11/tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 49.8MB/s
# Collecting huggingface-hub==0.0.8
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 43.3MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, sacremoses, transformers
# Successfully installed huggingface-hub-0.0.8 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.7.0

# %%
#%%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import pandas as pd
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tqdm import *
import transformers
from transformers import BertTokenizer
from transformers import TFBertModel
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC, Accuracy
from sklearn.metrics import classification_report, multilabel_confusion_matrix, roc_auc_score, average_precision_score, recall_score, precision_score, matthews_corrcoef, accuracy_score, f1_score
from sklearn.metrics import roc_auc_score, accuracy_score
#%%

tokenizer = BertTokenizer.from_pretrained("distilbert-base-multilingual-cased")
padded_ids_train = []
mask_ids_train = []

for i in tqdm(range(len(train_sentences))):
    encoding = tokenizer.encode_plus(train_sentences[i], max_length=128, pad_to_max_length=True, do_lower_case= False)
    input_ids, attention_id = encoding["input_ids"], encoding["attention_mask"]
    padded_ids_train.append(input_ids)
    mask_ids_train.append(attention_id)

padded_ids_test = []
mask_ids_test = []

for i in tqdm(range(len(test_sentences))):
    encoding=tokenizer.encode_plus(test_sentences[i], max_length=128, pad_to_max_length=True, do_lower_case= False)
    input_ids, attention_id = encoding["input_ids"], encoding["attention_mask"]
    padded_ids_test.append(input_ids)
    mask_ids_test.append(attention_id)

train_id = np.array(padded_ids_train)
train_mask = np.array(mask_ids_train)
test_id = np.array(padded_ids_test)
test_mask = np.array(mask_ids_test)

#%%

input_1 = tf.keras.Input(shape = (128) , dtype=np.int32)
input_2 = tf.keras.Input(shape = (128) , dtype=np.int32)
model = TFBertModel.from_pretrained('distilbert-base-multilingual-cased')
md  = model([input_1 , input_2] , training = False )
x = tf.reshape(md.pooler_output , (-1 , md.pooler_output.shape[1]))
x = tf.keras.layers.Dense(128 , activation= tf.nn.relu)(x)
x = tf.keras.layers.Dropout(0.15)(x)
x = tf.keras.layers.Dense(1 , activation = tf.nn.sigmoid)(x)
model = tf.keras.Model(inputs = [input_1, input_2 ] , outputs = [x])
model.summary()

path= "modelo2.h5"
checkpoint = ModelCheckpoint(filepath=path, monitor='val_precision', verbose=1, save_best_only=True, mode='max', save_weights_only=True)
model.compile(optimizer=Adam(lr=3e-5),loss=tf.keras.losses.binary_crossentropy, metrics=tf.keras.metrics.Precision())

# Training model...
history = model.fit([train_id,train_mask], y_train, batch_size=4, epochs=10, callbacks=checkpoint, validation_split=0.1)

# Loading model...
model.load_weights('modelo2.h5')
y_pred = model.predict([test_id, test_mask])
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=29.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1961828.0, style=ProgressStyle(descript…
#   0%|          | 0/15728 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2111: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  93%|█████████▎| 14694/15728 [00:54<00:03, 275.83it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  94%|█████████▎| 14739/15728 [00:54<00:03, 308.87it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  94%|█████████▍| 14774/15728 [00:54<00:03, 315.24it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  94%|█████████▍| 14809/15728 [00:55<00:02, 315.73it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  94%|█████████▍| 14843/15728 [00:55<00:02, 299.07it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▍| 14882/15728 [00:55<00:02, 319.76it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▍| 14916/15728 [00:55<00:04, 202.41it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▌| 14943/15728 [00:55<00:03, 216.04it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▌| 14987/15728 [00:55<00:02, 254.42it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▌| 15025/15728 [00:55<00:02, 282.37it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▌| 15059/15728 [00:55<00:02, 293.60it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▌| 15098/15728 [00:56<00:01, 317.01it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▌| 15134/15728 [00:56<00:01, 326.79it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▋| 15169/15728 [00:56<00:02, 260.59it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15205/15728 [00:56<00:01, 283.04it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15237/15728 [00:56<00:01, 271.16it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15269/15728 [00:56<00:01, 279.06it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15300/15728 [00:56<00:01, 285.65it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15330/15728 [00:56<00:01, 276.78it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  98%|█████████▊| 15362/15728 [00:57<00:01, 286.77it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  98%|█████████▊| 15392/15728 [00:57<00:01, 225.38it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# ...
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  98%|█████████▊| 3849/3932 [00:14<00:00, 254.63it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  99%|█████████▊| 3881/3932 [00:15<00:00, 262.96it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# 100%|█████████▉| 3914/3932 [00:15<00:00, 279.73it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# 100%|██████████| 3932/3932 [00:15<00:00, 257.62it/s]
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466.0, style=ProgressStyle(description_…
# You are using a model of type distilbert to instantiate a model of type bert. This is not supported for all configurations of models and can yield errors.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=910749124.0, style=ProgressStyle(descri…
# Some layers from the model checkpoint at distilbert-base-multilingual-cased were not used when initializing TFBertModel: ['distilbert', 'vocab_layer_norm', 'vocab_projector', 'vocab_transform', 'activation_13']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFBertModel were not initialized from the model checkpoint at distilbert-base-multilingual-cased and are newly initialized: ['bert']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7f2c14f75de0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7f2c14f75de0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function wrap at 0x7f2c3081ddd0> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function wrap at 0x7f2c3081ddd0> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 177853440   input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 768)          0           tf_bert_model[0][1]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          98432       tf.reshape[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            129         dropout_37[0][0]
# ==================================================================================================
# Total params: 177,952,001
# Trainable params: 177,952,001
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/10
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 3539/3539 [==============================] - ETA: 0s - loss: 0.2612 - precision: 0.8873WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 3539/3539 [==============================] - 335s 89ms/step - loss: 0.2612 - precision: 0.8873 - val_loss: 0.2857 - val_precision: 0.9663
#
# Epoch 00001: val_precision improved from -inf to 0.96628, saving model to modelo2.h5
# Epoch 2/10
# 3539/3539 [==============================] - 303s 86ms/step - loss: 0.2518 - precision: 0.9000 - val_loss: 0.2648 - val_precision: 0.9295
#
# Epoch 00002: val_precision did not improve from 0.96628
# Epoch 3/10
# 3539/3539 [==============================] - 301s 85ms/step - loss: 0.2726 - precision: 0.8673 - val_loss: 0.6034 - val_precision: 0.5872
#
# Epoch 00003: val_precision did not improve from 0.96628
# Epoch 4/10
# 3539/3539 [==============================] - 301s 85ms/step - loss: 0.5038 - precision: 0.6492 - val_loss: 0.4693 - val_precision: 0.6975
#
# Epoch 00004: val_precision did not improve from 0.96628
# Epoch 5/10
# 3539/3539 [==============================] - 299s 85ms/step - loss: 0.4397 - precision: 0.7736 - val_loss: 0.6245 - val_precision: 0.9937
#
# Epoch 00005: val_precision improved from 0.96628 to 0.99371, saving model to modelo2.h5
# Epoch 6/10
# 3539/3539 [==============================] - 300s 85ms/step - loss: 0.6231 - precision: 0.7972 - val_loss: 0.6259 - val_precision: 0.9935
#
# Epoch 00006: val_precision did not improve from 0.99371
# Epoch 7/10
# 3539/3539 [==============================] - 300s 85ms/step - loss: 0.6308 - precision: 0.8939 - val_loss: 0.6420 - val_precision: 1.0000
#
# Epoch 00007: val_precision improved from 0.99371 to 1.00000, saving model to modelo2.h5
# Epoch 8/10
# 3539/3539 [==============================] - 300s 85ms/step - loss: 0.6422 - precision: 0.8995 - val_loss: 0.6522 - val_precision: 1.0000
#
# Epoch 00008: val_precision did not improve from 1.00000
# Epoch 9/10
# 3539/3539 [==============================] - 300s 85ms/step - loss: 0.6482 - precision: 0.7908 - val_loss: 0.6520 - val_precision: 1.0000
#
# Epoch 00009: val_precision did not improve from 1.00000
# Epoch 10/10
# 3539/3539 [==============================] - 298s 84ms/step - loss: 0.6480 - precision: 0.7007 - val_loss: 0.6524 - val_precision: 1.0000
#
# Epoch 00010: val_precision did not improve from 1.00000
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "precision")
plot_graphs(history, "loss")

# %%
tf.keras.utils.plot_model(model, "modelo2.png")

# %%
y_int = np.zeros_like(y_pred)
y_int[y_pred > 0.5] = 1

print('Classification report {}'.format(classification_report(y_test, y_int, zero_division=0)))
print('Confusion matrix {}'.format(multilabel_confusion_matrix(y_test, y_int)))
print('Accuracy is {}'.format(accuracy_score(y_test,y_int)))
print('Roc-auc score is {}'.format(roc_auc_score(y_test, y_pred)))
# Out:
# Classification report               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70      1966
#            1       0.99      0.15      0.26      1966
#
#     accuracy                           0.57      3932
#    macro avg       0.77      0.57      0.48      3932
# weighted avg       0.77      0.57      0.48      3932
#
# Confusion matrix [[[ 290 1676]
#   [   2 1964]]
#
#  [[1964    2]
#   [1676  290]]]
# Accuracy is 0.5732451678535097
# Roc-auc score is 0.5733116593482901

# %%
# Guardar el Modelo
#model.save('modelo2.h5')

# %%
#model.save(path) 
 
#new_model = keras.models.load_model('modelo2.h5')
 
# Recrea exactamente el mismo modelo 
#new_model = keras.experimental.load_from_saved_model('modelo2.h5')

# %%
mainpath = '/content/drive/MyDrive/Ordenar/DSRP/'
filename = 'validacion.xlsx'
fullpath = os.path.join(mainpath, filename)
validacion=pd.read_excel(fullpath)

# %%
validacion.head()
# Out:
#                                           Comentario  ... Clasificacion
# 0   3D Bones and organos, Bacteria interactiva y ...  ...             0
# 1          .BUENAS TARDES FE Y ALEGRIA Nª70 PRESENTE  ...             0
# 2  :buffering:Buenas tardes compañeros Jorstin Sa...  ...             0
# 3  Abraham Juarez Silva Director I.E. Monte Lima ...  ...             0
# 4  AlainJhon Reyes Leon del colegio 32645 de CARA...  ...             0
#
# [5 rows x 3 columns]

# %%
validacion = validacion.iloc[:480 ,:]

# %%
validacion.shape
# Out:
# (480, 3)

# %%
validacion['Comentario'] = validacion['Comentario'].apply(lambda x: clean_text(x))

# %% [markdown]
# Validación

# %%
validacion_sentences = validacion["Comentario"].fillna("fillna")

# %%
padded_ids_validacion = []
mask_ids_validacion = []

# %%
for i in tqdm(range(len(validacion_sentences))):
    encoding=tokenizer.encode_plus(validacion_sentences[i], max_length=128, pad_to_max_length=True, do_lower_case= False)
    input_ids, attention_id = encoding["input_ids"], encoding["attention_mask"]
    padded_ids_validacion.append(input_ids)
    mask_ids_validacion.append(attention_id)
# Out:
#   0%|          | 0/480 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2111: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  10%|▉         | 47/480 [00:00<00:00, 466.82it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  20%|██        | 98/480 [00:00<00:00, 477.43it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  30%|███       | 145/480 [00:00<00:00, 474.06it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  39%|███▉      | 189/480 [00:00<00:00, 462.45it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  50%|█████     | 240/480 [00:00<00:00, 473.04it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  60%|██████    | 290/480 [00:00<00:00, 479.16it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  72%|███████▏  | 346/480 [00:00<00:00, 499.36it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  82%|████████▏ | 393/480 [00:00<00:00, 426.45it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  91%|█████████ | 436/480 [00:01<00:00, 373.01it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# 100%|██████████| 480/480 [00:01<00:00, 444.90it/s]

# %%
validacion_id = np.array(padded_ids_validacion)
validacion_mask = np.array(mask_ids_validacion)

# %%
y_pred_validacion = model.predict([validacion_id, validacion_mask])
# Out:
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.

# %%
y_int_validacion = np.zeros_like(y_pred_validacion)
y_int_validacion[y_pred_validacion > 0.5] = 1

# %%
classesv = ["Clasificacion"]
y_validacion = validacion[classesv].values

# %%
print('Classification report {}'.format(classification_report(y_validacion, y_int_validacion, zero_division=0)))
print('Confusion matrix {}'.format(multilabel_confusion_matrix(y_validacion, y_int_validacion)))
print('accuracy {}'.format(accuracy_score(y_validacion,y_int_validacion)))
print('precisision {}'.format(precision_score(y_validacion,y_int_validacion)))
print('Roc-auc score is {}'.format(roc_auc_score(y_validacion, y_int_validacion)))
# Out:
# Classification report               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88       367
#            1       1.00      0.08      0.15       113
#
#     accuracy                           0.78       480
#    macro avg       0.89      0.54      0.51       480
# weighted avg       0.83      0.78      0.70       480
#
# Confusion matrix [[[  9 104]
#   [  0 367]]
#
#  [[367   0]
#   [104   9]]]
# accuracy 0.7833333333333333
# precisision 1.0
# Roc-auc score is 0.5398230088495575

# %%
#validacion['clasificacion_pred'] = validacion_pred.tolist()
validacion['clasificacion_pred_int'] = y_int_validacion.tolist()

# %%
validacion.head()
# Out:
#                                           Comentario  ... clasificacion_pred_int
# 0    bones and organos bacteria interactiva y xmind   ...                  [0.0]
# 1               buenas tardes fe y alegria  presente  ...                  [0.0]
# 2  bufferingbuenas tardes compañeros jorstin samp...  ...                  [0.0]
# 3  abraham juarez silva director ie monte lima  i...  ...                  [0.0]
# 4  alainjhon reyes leon del colegio  de carampayo...  ...                  [0.0]
#
# [5 rows x 4 columns]

# %%
validacion.to_excel('Prueba2.xlsx',index=False)
