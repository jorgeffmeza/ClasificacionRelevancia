# %% [markdown]
# <a href="https://colab.research.google.com/github/lmoroney/dlaicourse/blob/master/TensorFlow%20In%20Practice/Course%203%20-%20NLP/Course%203%20-%20Week%202%20-%20Lesson%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import string
import os
import re, string
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout, Input, Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D, MaxPooling1D, BatchNormalization, SpatialDropout1D, GlobalAveragePooling1D, concatenate, Activation, LSTM, Bidirectional
from keras import initializers, regularizers, constraints, optimizers, layers, callbacks
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import StratifiedKFold, cross_val_score, KFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#/content/drive/MyDrive/Ordenar/DSRP/df.xlsx
mainpath = '/content/drive/MyDrive/Ordenar/DSRP/'
filename = 'train.xlsx'
fullpath = os.path.join(mainpath, 'train.xlsx')
train=pd.read_excel(fullpath, usecols=['Comentario','Clasificación'])

fullpath = os.path.join(mainpath, 'test.xlsx')
test=pd.read_excel(fullpath, usecols=['Comentario','Clasificación'])

# %%
train.shape, test.shape
# Out:
# ((15728, 2), (3932, 2))

# %%
#print('Loading data...')
#train = pd.read_csv(r"train.csv")
#test = pd.read_csv(r"test.csv")
#test_labels = pd.read_csv(r"test_labels.csv")

#test = pd.concat([test, test_labels], axis=1)
#test = test[test['toxic']!=-1]

classes = ["Clasificación"]
y_train = train[classes].values
y_test = test[classes].values

train_sentences = train["Comentario"].fillna("fillna")
test_sentences = test["Comentario"].fillna("fillna")

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/00/92/6153f4912b84ee1ab53ab45663d23e7cf3704161cb5ef18b0c07e207cef2/transformers-4.7.0-py3-none-any.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 8.4MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/d4/e2/df3543e8ffdab68f5acc73f613de9c2b155ac47f162e725dcac87c521c11/tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 33.4MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 34.1MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.5.0)
# Collecting huggingface-hub==0.0.8
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from transformers) (3.13)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.0.8 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.7.0

# %%
#%%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import pandas as pd
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tqdm import *
import transformers
from transformers import BertTokenizer
from transformers import TFBertModel
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC, Accuracy
from sklearn.metrics import classification_report, multilabel_confusion_matrix, roc_auc_score, average_precision_score, recall_score, precision_score, matthews_corrcoef, accuracy_score, f1_score
from sklearn.metrics import roc_auc_score, accuracy_score

#%%
#/content/drive/MyDrive/Ordenar/DSRP/df.xlsx
#mainpath = '/content/drive/MyDrive/Ordenar/DSRP/'
#filename = 'train.xlsx'
#fullpath = os.path.join(mainpath, filename)
#train = pd.read_excel(fullpath ,engine='openpyxl')

#filename = 'test.xlsx'
#fullpath = os.path.join(mainpath, filename)
#test = pd.read_excel(fullpath ,engine='openpyxl')

#train_sentences = train["Comentario"].values
#y_train = train["Clasificación"].values
#test_sentences = test["Comentario"].values

#%%

tokenizer = BertTokenizer.from_pretrained("dccuchile/bert-base-spanish-wwm-uncased")
padded_ids_train = []
mask_ids_train = []

for i in tqdm(range(len(train_sentences))):
    encoding = tokenizer.encode_plus(train_sentences[i], max_length=128, pad_to_max_length=True, do_lower_case= False)
    input_ids, attention_id = encoding["input_ids"], encoding["attention_mask"]
    padded_ids_train.append(input_ids)
    mask_ids_train.append(attention_id)

padded_ids_test = []
mask_ids_test = []

for i in tqdm(range(len(test_sentences))):
    encoding=tokenizer.encode_plus(test_sentences[i], max_length=128, pad_to_max_length=True, do_lower_case= False)
    input_ids, attention_id = encoding["input_ids"], encoding["attention_mask"]
    padded_ids_test.append(input_ids)
    mask_ids_test.append(attention_id)

train_id = np.array(padded_ids_train)
train_mask = np.array(mask_ids_train)
test_id = np.array(padded_ids_test)
test_mask = np.array(mask_ids_test)

#%%

input_1 = tf.keras.Input(shape = (128) , dtype=np.int32)
input_2 = tf.keras.Input(shape = (128) , dtype=np.int32)
model = TFBertModel.from_pretrained("dccuchile/bert-base-spanish-wwm-uncased")
md  = model([input_1 , input_2] , training = False )
x = tf.reshape(md.pooler_output , (-1 , md.pooler_output.shape[1]))
x = tf.keras.layers.Dense(128 , activation= tf.nn.relu)(x)
x = tf.keras.layers.Dropout(0.15)(x)
x = tf.keras.layers.Dense(1 , activation = tf.nn.sigmoid)(x)
model = tf.keras.Model(inputs = [input_1, input_2 ] , outputs = [x])
model.summary()

path= "modelo1.h5"
checkpoint = ModelCheckpoint(filepath=path, monitor='val_precision', verbose=1, save_best_only=True, mode='max', save_weights_only=True)
model.compile(optimizer=Adam(lr=3e-5),loss=tf.keras.losses.binary_crossentropy, metrics=tf.keras.metrics.Precision())

# Training model...
history = model.fit([train_id,train_mask], y_train, batch_size=4, epochs=10, callbacks=checkpoint, validation_split=0.1)

# Loading model...
model.load_weights('modelo1.h5')
y_pred = model.predict([test_id, test_mask])
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=247723.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=134.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=310.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=486125.0, style=ProgressStyle(descripti…
#   0%|          | 0/15728 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2111: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#   0%|          | 28/15728 [00:00<00:57, 274.13it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  93%|█████████▎| 14676/15728 [01:21<00:05, 197.32it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  93%|█████████▎| 14699/15728 [01:21<00:05, 204.52it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  94%|█████████▎| 14726/15728 [01:21<00:04, 219.03it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  94%|█████████▍| 14749/15728 [01:21<00:04, 211.48it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  94%|█████████▍| 14771/15728 [01:22<00:04, 209.29it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  94%|█████████▍| 14795/15728 [01:22<00:04, 216.98it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  94%|█████████▍| 14818/15728 [01:22<00:06, 149.55it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  94%|█████████▍| 14843/15728 [01:22<00:05, 169.50it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▍| 14864/15728 [01:22<00:04, 173.28it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▍| 14887/15728 [01:22<00:04, 185.76it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▍| 14908/15728 [01:22<00:04, 191.66it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▍| 14929/15728 [01:23<00:04, 173.81it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▌| 14949/15728 [01:23<00:04, 176.45it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▌| 14968/15728 [01:23<00:05, 134.64it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▌| 14984/15728 [01:23<00:05, 133.39it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▌| 14999/15728 [01:23<00:05, 126.30it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  95%|█████████▌| 15013/15728 [01:23<00:07, 102.04it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▌| 15037/15728 [01:23<00:05, 122.82it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▌| 15053/15728 [01:24<00:05, 127.80it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▌| 15073/15728 [01:24<00:04, 143.01it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▌| 15095/15728 [01:24<00:03, 159.57it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▌| 15125/15728 [01:24<00:03, 184.97it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▋| 15153/15728 [01:24<00:02, 203.31it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▋| 15176/15728 [01:24<00:03, 173.63it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15196/15728 [01:24<00:04, 132.90it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15222/15728 [01:24<00:03, 152.68it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15245/15728 [01:25<00:02, 169.78it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15269/15728 [01:25<00:02, 185.18it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15295/15728 [01:25<00:02, 202.43it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 15321/15728 [01:25<00:01, 215.43it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  98%|█████████▊| 15349/15728 [01:25<00:01, 229.81it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  98%|█████████▊| 15374/15728 [01:25<00:01, 226.94it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# ...
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 3813/3932 [00:21<00:00, 177.31it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  97%|█████████▋| 3833/3932 [00:21<00:00, 172.50it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  98%|█████████▊| 3855/3932 [00:21<00:00, 182.98it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  99%|█████████▊| 3875/3932 [00:22<00:00, 117.79it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  99%|█████████▉| 3891/3932 [00:22<00:00, 125.01it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# 100%|█████████▉| 3913/3932 [00:22<00:00, 143.03it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# 100%|█████████▉| 3931/3932 [00:22<00:00, 125.69it/s]Keyword arguments {'do_lower_case': False} not recognized.
# 100%|██████████| 3932/3932 [00:22<00:00, 174.28it/s]
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=650.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=536635336.0, style=ProgressStyle(descri…
# Some layers from the model checkpoint at dccuchile/bert-base-spanish-wwm-uncased were not used when initializing TFBertModel: ['mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFBertModel were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-uncased and are newly initialized: ['bert/pooler/dense/kernel:0', 'bert/pooler/dense/bias:0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7ff5e8195de0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7ff5e8195de0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function wrap at 0x7ff603a3edd0> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function wrap at 0x7ff603a3edd0> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# tf_bert_model (TFBertModel)     TFBaseModelOutputWit 109850880   input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 768)          0           tf_bert_model[0][1]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          98432       tf.reshape[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 128)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            129         dropout_37[0][0]
# ==================================================================================================
# Total params: 109,949,441
# Trainable params: 109,949,441
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/10
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 3539/3539 [==============================] - ETA: 0s - loss: 0.1916 - precision: 0.9233WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 3539/3539 [==============================] - 460s 122ms/step - loss: 0.1916 - precision: 0.9233 - val_loss: 0.1582 - val_precision: 0.9484
#
# Epoch 00001: val_precision improved from -inf to 0.94836, saving model to modelo1.h5
# Epoch 2/10
# 3539/3539 [==============================] - 413s 117ms/step - loss: 0.1365 - precision: 0.9504 - val_loss: 0.1663 - val_precision: 0.9389
#
# Epoch 00002: val_precision did not improve from 0.94836
# Epoch 3/10
# 3539/3539 [==============================] - 412s 116ms/step - loss: 0.0953 - precision: 0.9677 - val_loss: 0.1868 - val_precision: 0.8940
#
# Epoch 00003: val_precision did not improve from 0.94836
# Epoch 4/10
# 3539/3539 [==============================] - 415s 117ms/step - loss: 0.0763 - precision: 0.9731 - val_loss: 0.2024 - val_precision: 0.9611
#
# Epoch 00004: val_precision improved from 0.94836 to 0.96114, saving model to modelo1.h5
# Epoch 5/10
# 3539/3539 [==============================] - 413s 117ms/step - loss: 0.0781 - precision: 0.9758 - val_loss: 0.2831 - val_precision: 0.9220
#
# Epoch 00005: val_precision did not improve from 0.96114
# Epoch 6/10
# 3539/3539 [==============================] - 414s 117ms/step - loss: 0.0663 - precision: 0.9785 - val_loss: 0.2543 - val_precision: 0.9426
#
# Epoch 00006: val_precision did not improve from 0.96114
# Epoch 7/10
# 3539/3539 [==============================] - 415s 117ms/step - loss: 0.0715 - precision: 0.9797 - val_loss: 0.3144 - val_precision: 0.9497
#
# Epoch 00007: val_precision did not improve from 0.96114
# Epoch 8/10
# 2080/3539 [================>.............] - ETA: 2:43 - loss: 0.1374 - precision: 0.9531

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "precision")
plot_graphs(history, "loss")

# %%
y_int = np.zeros_like(y_pred)
y_int[y_pred > 0.5] = 1
# Out:
# Classification report               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      1966
#            1       0.96      0.84      0.90      1966
#
#     accuracy                           0.90      3932
#    macro avg       0.91      0.90      0.90      3932
# weighted avg       0.91      0.90      0.90      3932
#
# Confusion matrix [[[1656  310]
#   [  64 1902]]
#
#  [[1902   64]
#   [ 310 1656]]]
# Accuracy is 0.904883011190234
# Roc-auc score is 0.8850678989412071

# %%
print('Classification report {}'.format(classification_report(y_test, y_int, zero_division=0)))
print('Confusion matrix {}'.format(multilabel_confusion_matrix(y_test, y_int)))
print('accuracy {}'.format(accuracy_score(y_test,y_int)))
print('precisision {}'.format(precision_score(y_test,y_int)))
print('Roc-auc score is {}'.format(roc_auc_score(y_test, y_pred)))
# Out:
# Classification report               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      1966
#            1       0.96      0.84      0.90      1966
#
#     accuracy                           0.90      3932
#    macro avg       0.91      0.90      0.90      3932
# weighted avg       0.91      0.90      0.90      3932
#
# Confusion matrix [[[1656  310]
#   [  64 1902]]
#
#  [[1902   64]
#   [ 310 1656]]]
# accuracy 0.904883011190234
# precisision 0.9627906976744186
# Roc-auc score is 0.8850678989412071

# %%
print('Confusion matrix {}'.format(multilabel_confusion_matrix(y_test, y_int)))
# Out:
# Confusion matrix [[[1656  310]
#   [  64 1902]]
#
#  [[1902   64]
#   [ 310 1656]]]

# %%
# Guardar el Modelo
#model.save('modelo1.h5')

# %%
#model.save(path) 
 
#new_model = keras.models.load_model('modelo1.h5') 
 
# Recrea exactamente el mismo modelo 
#new_model = keras.experimental.load_from_saved_model('modelo1.h5')

# %%
mainpath = '/content/drive/MyDrive/Ordenar/DSRP/'
filename = 'validacion.xlsx'
fullpath = os.path.join(mainpath, filename)
validacion=pd.read_excel(fullpath)

# %%
validacion.head()
# Out:
#                                           Comentario  ... Clasificacion
# 0   3D Bones and organos, Bacteria interactiva y ...  ...             0
# 1          .BUENAS TARDES FE Y ALEGRIA Nª70 PRESENTE  ...             0
# 2  :buffering:Buenas tardes compañeros Jorstin Sa...  ...             0
# 3  Abraham Juarez Silva Director I.E. Monte Lima ...  ...             0
# 4  AlainJhon Reyes Leon del colegio 32645 de CARA...  ...             0
#
# [5 rows x 3 columns]

# %%
validacion = validacion.iloc[:480 ,:]

# %%
validacion.shape
# Out:
# (480, 3)

# %% [markdown]
# Validación

# %%
validacion_sentences = validacion["Comentario"].fillna("fillna")

# %%
padded_ids_validacion = []
mask_ids_validacion = []

# %%
for i in tqdm(range(len(validacion_sentences))):
    encoding=tokenizer.encode_plus(validacion_sentences[i], max_length=128, pad_to_max_length=True, do_lower_case= False)
    input_ids, attention_id = encoding["input_ids"], encoding["attention_mask"]
    padded_ids_validacion.append(input_ids)
    mask_ids_validacion.append(attention_id)
# Out:
#   0%|          | 0/480 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2111: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#   8%|▊         | 36/480 [00:00<00:01, 359.84it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  18%|█▊        | 87/480 [00:00<00:01, 392.80it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  28%|██▊       | 134/480 [00:00<00:00, 411.01it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  36%|███▋      | 174/480 [00:00<00:00, 407.56it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  44%|████▍     | 212/480 [00:00<00:00, 388.09it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  51%|█████▏    | 246/480 [00:00<00:00, 364.05it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  58%|█████▊    | 279/480 [00:00<00:00, 351.93it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  65%|██████▌   | 312/480 [00:00<00:00, 335.79it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  73%|███████▎  | 351/480 [00:00<00:00, 348.71it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  80%|████████  | 385/480 [00:01<00:00, 305.05it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  87%|████████▋ | 416/480 [00:01<00:00, 290.87it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
#  96%|█████████▋| 463/480 [00:01<00:00, 327.07it/s]Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# Keyword arguments {'do_lower_case': False} not recognized.
# 100%|██████████| 480/480 [00:01<00:00, 342.39it/s]

# %%
validacion_id = np.array(padded_ids_validacion)
validacion_mask = np.array(mask_ids_validacion)

# %%
y_pred_validacion = model.predict([validacion_id, validacion_mask])

# %%
y_int_validacion = np.zeros_like(y_pred_validacion)
y_int_validacion[y_pred_validacion > 0.5] = 1

# %%
classesv = ["Clasificacion"]
y_validacion = validacion[classesv].values

# %%
print('Classification report {}'.format(classification_report(y_validacion, y_int_validacion, zero_division=0)))
print('Confusion matrix {}'.format(multilabel_confusion_matrix(y_validacion, y_int_validacion)))
print('accuracy {}'.format(accuracy_score(y_validacion,y_int_validacion)))
print('precisision {}'.format(precision_score(y_validacion,y_int_validacion)))
print('Roc-auc score is {}'.format(roc_auc_score(y_validacion, y_int_validacion)))
# Out:
# Classification report               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       367
#            1       0.90      0.91      0.91       113
#
#     accuracy                           0.96       480
#    macro avg       0.94      0.94      0.94       480
# weighted avg       0.96      0.96      0.96       480
#
# Confusion matrix [[[103  10]
#   [ 11 356]]
#
#  [[356  11]
#   [ 10 103]]]
# accuracy 0.95625
# precisision 0.9035087719298246
# Roc-auc score is 0.940765836367582

# %%
#validacion['clasificacion_pred'] = validacion_pred.tolist()
validacion['clasificacion_pred_int'] = y_int_validacion.tolist()

# %%
validacion.head()
# Out:
#                                           Comentario  ... clasificacion_pred_int
# 0   3D Bones and organos, Bacteria interactiva y ...  ...                  [1.0]
# 1          .BUENAS TARDES FE Y ALEGRIA Nª70 PRESENTE  ...                  [0.0]
# 2  :buffering:Buenas tardes compañeros Jorstin Sa...  ...                  [0.0]
# 3  Abraham Juarez Silva Director I.E. Monte Lima ...  ...                  [0.0]
# 4  AlainJhon Reyes Leon del colegio 32645 de CARA...  ...                  [0.0]
#
# [5 rows x 4 columns]

# %%
validacion.to_excel('modelo1.xlsx',index=False)
